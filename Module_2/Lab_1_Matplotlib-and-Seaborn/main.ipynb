# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# %matplotlib inline

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y)

plt.xlabel('x')
plt.ylabel('y')

plt.title("x vs y")

plt.show()

# %%
plt.plot(x, z)

plt.xlabel('x')
plt.ylabel('z')

plt.title("x vs z")

plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(1,2)

ax1.plot(x,y)
ax1.set_title('x-y') 
ax1.set_xlabel('x')
ax1.set_ylabel('y')

ax2.plot(x, z)
ax2.set_title('x-z')
ax2.set_xlabel('x')
ax2.set_ylabel('z')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.6, 
                    hspace=0.4)

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, [ax1, ax2] = plt.subplots(1,2,figsize=(10,5))

ax1.plot(x,y)
ax1.set_title('x-y') 
ax1.set_xlabel('x')
ax1.set_ylabel('y')

ax2.plot(x, z)
ax2.set_title('x-z')
ax2.set_xlabel('x')
ax2.set_ylabel('z')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.6, 
                    hspace=0.4)

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
from math import e

y1=x**2
y2=e**x


plt.plot(x, y1, label = "normal")

plt.plot(x, y2, label = "logarithmic")
plt.xlabel('x - axis')

plt.ylabel('y - axis')
plt.yscale("log") 

plt.legend()

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit=pd.read_csv('/Users/ildem/Desktop/Lab_1_Matplotlib-and-Seaborn/Fitbit2.csv')
fitbit.columns
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

monthly=fitbit[['Months_encoded', 'Steps']].groupby(['Months_encoded']).median(['Steps'])

monthly.reset_index(inplace=True)

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

work_or_weekend=fitbit[['Work_or_Weekend', 'Steps']].groupby(['Work_or_Weekend']).median(['Steps'])

work_or_weekend.reset_index(inplace=True)
work_or_weekend
# Out:
#    Work_or_Weekend    Steps
# 0                0   9998.0
# 1                1  10445.5

# %%
x1=monthly.Months_encoded
y1=monthly.Steps

x2=work_or_weekend.Work_or_Weekend
y2=work_or_weekend.Steps

fig, [ax1, ax2] = plt.subplots(1,2,figsize=(12,4), gridspec_kw={'width_ratios': [3, 1]})

ax1.bar(x1,y1)
ax1.set_title('monthly steps') 
ax1.set_xlabel('months')
ax1.set_ylabel('steps')


ax2.bar(x2, y2, width=0.6)
ax2.set_title('work day/weekend')
ax2.set_xlabel('work or week days')
ax2.set_ylabel('steps')

               
plt.show()

fig.savefig('/Users/ildem/Desktop/steps.jpg', dpi=150)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
x1=fitbit['Minutes Lightly Active']
y1=fitbit.Steps

x2=fitbit['Minutes Very Active']
y2=fitbit.Steps

x3=fitbit['Minutes Sedentary']
y3=fitbit.Steps


fig, [ax1, ax2, ax3] = plt.subplots(1,3,figsize=(16,4))

ax1.scatter(x1,y1)
ax1.set_title('Minutes Lightly Active vs Steps') 
ax1.set_xlabel('Minutes Lightly Active')
ax1.set_ylabel('Steps')


ax2.scatter(x2, y2)
ax2.set_title('Minutes Very Active vs Steps')
ax2.set_xlabel('Minutes Very Active')
ax2.set_ylabel('Steps')

ax3.scatter(x2, y2)
ax3.set_title('Minutes Sedentary vs Steps')
ax3.set_xlabel('Minutes Sedentary')
ax3.set_ylabel('Steps')


plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic=pd.read_csv('/Users/ildem/Desktop/Lab_1_Matplotlib-and-Seaborn/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['float64', 'int64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include=['object'])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(titanic.Age)
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, [ax1, ax2, ax3] = plt.subplots(1,3,figsize=(12,4))

ax1.hist(titanic.Age, bins=10)
ax1.set_xlabel('Age')
ax1.set_title('Bins=10')

ax2.hist(titanic.Age, bins=20)
ax2.set_xlabel('Age')
ax2.set_title('Bins=20')

ax3.hist(titanic.Age, bins=50)
ax3.set_xlabel('Age')
ax3.set_title('Bins=50')

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""
As we decrease the size of the bins, we get a more detailed view of the distribution.

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.displot(titanic.Age)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

y=pd.DataFrame(titanic.Gender.value_counts())
plt.figure(figsize=(3,5))
plt.bar(y.index, y.Gender)
# Out:
# <BarContainer object of 2 artists>

# %%
# Method 2 - seaborn
# your code here
sns.displot(titanic.Gender)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
cla=pd.DataFrame(titanic.Pclass.value_counts())
plt.figure(figsize=(3,5))
plt.xticks(cla.index)
plt.bar(cla.index, cla.Pclass)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
plt.boxplot(titanic.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12bcdb100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x12bcdb820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x12bccbd60>],
#  'medians': [<matplotlib.lines.Line2D at 0x12bcdbf40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12bce7310>],
#  'means': []}

# %%
"""
your comments here
We can show the statistics such as median, first and third quartiles, minimum and maximum with a boxplot.
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
The median is smaller than 30 and most of the passengers were under 40.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
vp=plt.violinplot(titanic.Age, vert=False, showmeans = True,  showmedians = True)
plt.setp(vp['bodies'], facecolor='blue')
# Out:
# [None]

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
We can see median and mean at the same time on this plot.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here


plt.scatter(titanic.Age, titanic.Fare)
plt.xlabel('Age')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
# Method 2 - seaborn
# your code here
sns.jointplot(titanic.Age, titanic.Fare)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr(),  center=True, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
Passenger class and Fare are the most correlated features.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
titanic.boxplot(column='Age', by='Pclass')
# Out:
# <AxesSubplot:title={'center':'Age'}, xlabel='Pclass'>

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g = sns.FacetGrid(titanic, col='Gender')
g.map(plt.hist, "Age")
