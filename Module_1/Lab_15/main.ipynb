# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
pip install stackapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from stackapi import StackAPI

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1643673670, todate=1646092750)
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 245,
#  'total': 0,
#  'items': [{'tags': ['algorithm',
#     'tree',
#     'depth-first-search',
#     'breadth-first-search'],
#    'owner': {'reputation': 11,
#     'user_id': 18313081,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/131fcd64f16f7c208361571df5b25fe9?s=256&d=identicon&r=PG',
#     'display_name': 'meow33',
#     'link': 'https://stackoverflow.com/users/18313081/meow33'},
#    'is_answered': True,
#    'view_count': 155,
#    'answer_count': 2,
#    'score': 1,
#    'last_activity_date': 1646151097,
#    'creation_date': 1645841183,
#    'last_edit_date': 1645845336,
#    'question_id': 71273541,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71273541/convert-a-n-ary-tree-from-bottom-up-without-recursion',
#    'title': 'Convert a N-ary tree from bottom up without recursion'},
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', fromdate=1643673670, todate=1646092750)
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 96,
#  'total': 0,
#  'items': [{'owner': {'reputation': 1,
#     'user_id': 18297791,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a7f902b3e95847825e289a39c1967222?s=256&d=identicon&r=PG',
#     'display_name': 'Arumugasami Murugesan',
#     'link': 'https://stackoverflow.com/users/18297791/arumugasami-murugesan'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646151540,
#    'last_edit_date': 1646151540,
#    'creation_date': 1645696483,
#    'answer_id': 71250120,
#    'question_id': 71211220,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 13,
#     'user_id': 18305810,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/e5e15cb68d04c5bf654dd8db7eb557b2?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Bala Murugan',
# ...

# %%
# your code here
most_voted = SITE.fetch('questions', fromdate=1646092800, todate=1646151383, min=5, tagged='python', sort='votes')

# %%
most_voted
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 94,
#  'total': 0,
#  'items': []}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
badges = SITE.fetch('badges', ids=[6784, 6473])
badges
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 21,
#  'total': 0,
#  'items': [{'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'silver',
#    'badge_id': 6784,
#    'link': 'https://stackoverflow.com/badges/6784/asterisk',
#    'name': 'asterisk'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'gold',
#    'badge_id': 6473,
#    'link': 'https://stackoverflow.com/badges/6473/sql-server-2012',
#    'name': 'sql-server-2012'}]}
